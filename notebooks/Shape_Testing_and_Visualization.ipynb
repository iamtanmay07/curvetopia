# %%
# Assuming your Jupyter Notebook is in the root directory of your project and Shape_Identification_Module.py is in the src/ directory
import sys
sys.path.append('../src/')  # Adjust this path if your directory structure is different
from Shape_Identification_Module import is_straight_line, is_circle, is_rectangle, is_regular_polygon, is_star_shape, is_ellipse

# %%
import numpy as np
import pandas as pd

# Function to load data if it's stored in a CSV file
def load_data(file_path):
    return pd.read_csv(file_path).values

# Example data load
# points = load_data('../data/raw/sample_polyline2.csv') # this is for straightLine Testing
points = load_data('../data/EllipseShape.csv')

# %%
# Testing the shape identification functions
is_line = is_straight_line(points)
is_circ = is_circle(points)
is_rect = is_rectangle(points)
is_poly = is_regular_polygon(points, 5)  # Check for pentagon as an example
is_star = is_star_shape(points)
is_ellip = is_ellipse(points)

print(f"Is Straight Line: {is_line}")
print(f"Is Circle: {is_circ}")
print(f"Is Rectangle: {is_rect}")
print(f"Is Regular Polygon: {is_poly}")
print(f"Is Star Shape: {is_star}")
print(f"Is Ellipse: {is_ellip}")

# Visualization (optional, depends on your data and what you want to see)
import matplotlib.pyplot as plt

plt.scatter(points[:, 0], points[:, 1], c='blue', label='Data Points')

plt.legend()
plt.axis('equal')
plt.show()
# Out:
# Is Straight Line: False
# Is Circle: False
# Is Rectangle: False
# Is Regular Polygon: False
# Is Star Shape: False
# Is Ellipse: False
